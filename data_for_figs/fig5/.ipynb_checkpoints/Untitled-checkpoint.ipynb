# %%
import pandas as pd
import glob
import numpy as np

# %%
names = glob.glob('*smooth*')

# %%
names
# Out:
# ['rapAheatdataset_alldone_with_largeMCMC195_infoshift_no_weightv2_smoothed_redo.txt',
#  'arcAAnaerodataset_alldone_with_largeMCMC194_infoshift_no_weightv2_smoothed.txt',
#  'aphAAnaerodataset_alldone_with_largeMCMC195_infoshift_no_weightv2_smoothed.txt',
#  'tigglpRdataset_alldone_with_largeMCMC194_infoshift_no_weightv2_smoothed_redo.txt',
#  'rhleLBdataset_5759_RNA41_with_tagv3_0_160MCMC194_infoshift_no_weightv2_smoothed.txt',
#  'yehUAnaerodataset_alldone_with_largeMCMC194_infoshift_no_weightv2_smoothed.txt',
#  'tff-rpsB-tsfarabinosedataset_alldone_with_largeMCMC195infoshift_smoothv2',
#  'ykgEarabinosedataset_alldone_with_largeMCMC194infoshift_smoothv2',
#  'yeiQAnaerodataset_alldone_with_largeMCMC194_infoshift_no_weightv2_smoothed.txt',
#  'tff-rpsB-tsfheatdataset_alldone_with_largeMCMC195_infoshift_no_weightv2_smoothed.txt',
#  'maoPglpRdataset_alldone_with_largeMCMC194_infoshift_no_weightv2_smoothed_redo.txt',
#  'ykgEAnaerodataset_alldone_with_largeMCMC194_infoshift_no_weightv2_smoothed.txt',
#  'rapAarabinosedataset_alldone_with_largeMCMC194infoshift_smoothv2',
#  'fdhELBdataset_alldone_with_largeMCMC195_infoshift_no_weightv2_smoothed.txt',
#  'yehUarabinosedataset_alldone_with_largeMCMC194infoshift_smoothv2',
#  'rhleM9dataset_5760_RNA40_with_tagv3_0_160_MCMC194_infoshift_no_weightv2_smoothed.txt',
#  'tigarabinosedataset_alldone_with_largeMCMC194infoshift_smoothv2',
#  'maoPheatdataset_alldone_with_largeMCMC195_infoshift_no_weightv2_smoothed_redo.txt',
#  'yeiQarabinosedataset_alldone_with_largeMCMC194infoshift_smoothv2',
#  'tigM9dataset_alldone_with_largeMCMC194_infoshift_no_weightv2_smoothed.txt',
#  'tff-rpsB-tsfglpRdataset_alldone_with_largeMCMC194_infoshift_no_weightv2_smoothed_redo.txt',
#  'maoParabinosedataset_alldone_with_largeMCMC194infoshift_smoothv2',
#  'aphAarabinosedataset_alldone_with_largeMCMC194infoshift_smoothv2',
#  'arcAarabinosedataset_alldone_with_largeMCMC194infoshift_smoothv2',
#  'fdhEAnaerodataset_alldone_with_largeMCMC194_infoshift_no_weightv2_smoothed.txt']

# %%
def sliding_window(y,windowsize=3):
    out_vec = np.zeros_like(y)
    for i in range(len(y)-windowsize):
        out_vec[i] = np.sum(y[i:i+windowsize])/windowsize
    return out_vec

# %%
infodf = pd.DataFrame()
#infodf['pos'] = range(1,158)
infodf['pos'] = range(160)

# %%
possible_growths = ['arabinose','hdfR','M9','SS','LB','Anaero','glpR','heat']

# %%
for i,name in enumerate(names):
    tempdf = pd.io.parsers.read_csv(name,delim_whitespace=True)
    for x in possible_growths:
        if x in name:
            gene = name.split(x)[0]
            growth = x
    if growth == 'arabinose':
    #    tempdf['info'] = sliding_window(tempdf['info'])
    infodf[gene + '_' + growth + '_info'] = tempdf['info']

# %%
infodf
# Out:
#      pos  rapA_heat_info  arcA_Anaero_info  aphA_Anaero_info  tig_glpR_info  \
# 0      0        0.000039          0.000126          0.000004   1.503666e-05
# 1      1        0.000094          0.000100          0.000011   1.836229e-05
# 2      2        0.000113          0.000002         -0.000002   5.272406e-05
# 3      3        0.000112         -0.000029         -0.000014   1.647753e-05
# 4      4        0.000147          0.000044         -0.000163   9.337660e-06
# ..   ...             ...               ...               ...            ...
# 155  155       -0.000077         -0.000085          0.000008   1.908591e-07
# 156  156       -0.000126         -0.000094         -0.000005   1.158118e-04
# 157  157        0.000000          0.000000          0.000000   0.000000e+00
# 158  158        0.000000          0.000000          0.000000   0.000000e+00
# 159  159        0.000000          0.000000          0.000000   0.000000e+00
#
#      rhle_LB_info  yehU_Anaero_info  tff-rpsB-tsf_arabinose_info  \
# 0       -0.000178          0.000072                 1.000109e-05
# 1       -0.000149         -0.000099                 9.903731e-07
# 2       -0.000096         -0.000127                 1.155834e-04
# 3        0.000123         -0.000125                 9.704432e-06
# 4        0.000147         -0.000001                 2.214803e-05
# ..            ...               ...                          ...
# 155      0.000143          0.000045                 2.657885e-04
# 156      0.000138         -0.000036                 2.865498e-04
# 157      0.000000          0.000000                -7.025716e-05
# 158      0.000000          0.000000                -2.280001e-04
# 159      0.000000          0.000000                -1.483575e-06
#
#      ykgE_arabinose_info  yeiQ_Anaero_info  ...  rhle_M9_info  \
# 0          -9.643515e-06          0.000183  ...      0.000001
# 1          -1.919673e-06          0.000173  ...      0.000004
# 2          -7.011544e-05          0.000131  ...      0.000006
# 3          -2.283774e-05         -0.000163  ...      0.000003
# 4          -1.869234e-05         -0.000146  ...      0.000002
# ..                   ...               ...  ...           ...
# 155        -1.172817e-04          0.000139  ...     -0.000013
# 156        -8.835299e-06          0.000116  ...     -0.000002
# 157        -9.638729e-07          0.000000  ...      0.000000
# 158        -7.319348e-08          0.000000  ...      0.000000
# 159        -2.790969e-04          0.000000  ...      0.000000
#
#      tig_arabinose_info  maoP_heat_info  yeiQ_arabinose_info  tig_M9_info  \
# 0         -3.728998e-05       -0.000116        -1.157862e-04    -0.000008
# 1         -4.483955e-06       -0.000109        -4.451387e-04    -0.000008
# 2         -3.519738e-07       -0.000024        -3.809947e-04    -0.000014
# 3         -1.534859e-05       -0.000068         1.885668e-05     0.000004
# 4         -6.354177e-06       -0.000073         7.715881e-05     0.000007
# ..                  ...             ...                  ...          ...
# 155       -8.398345e-09        0.000268        -2.780814e-05    -0.000092
# 156       -3.863230e-05        0.000304        -4.743774e-05    -0.000130
# 157       -2.489571e-05        0.000000        -4.257389e-07     0.000000
# 158       -3.877920e-04        0.000000        -4.394617e-05     0.000000
# 159       -1.430485e-04        0.000000        -3.741302e-04     0.000000
#
#      tff-rpsB-tsf_glpR_info  maoP_arabinose_info  aphA_arabinose_info  \
# 0                 -0.000023            -0.000275            -0.000034
# 1                 -0.000052             0.000329            -0.000058
# 2                 -0.000062             0.000123            -0.000038
# 3                 -0.000023            -0.000022            -0.000002
# 4                 -0.000026            -0.000049            -0.000209
# ..                      ...                  ...                  ...
# 155               -0.000115             0.000147            -0.000010
# 156               -0.000088             0.000048            -0.000080
# 157                0.000000            -0.000875            -0.000004
# 158                0.000000            -0.000141            -0.000034
# 159                0.000000            -0.000074            -0.000001
#
#      arcA_arabinose_info  fdhE_Anaero_info
# 0              -0.000019     -6.796957e-07
# 1              -0.000243     -2.581884e-05
# 2               0.000066     -2.685111e-05
# 3              -0.000043     -7.279059e-07
# 4              -0.000299     -3.973885e-05
# ..                   ...               ...
# 155             0.000052      9.031562e-05
# 156            -0.000112      7.324064e-05
# 157            -0.000002      0.000000e+00
# 158            -0.000206      0.000000e+00
# 159            -0.000016      0.000000e+00
#
# [160 rows x 26 columns]

# %%
infodf.to_csv('infomation_fig3.csv')
